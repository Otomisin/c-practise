# %% [markdown]
# ## Consuming APIs

# %%
import requests
import pandas as pd
from IPython.display import JSON

response = requests.get("https://randomuser.me/api/")
responseText = response.text
responseText
JSON(responseText)

# %% [markdown]
# ## CAT API

# %%
import requests
import pandas as pd

result = requests.get('https://api.thecatapi.com/')

# Get the content of the API

# %% [markdown]
# ### Interacting with API

# %%
response = requests.get('https://api.thecatapi.com/v1/images/0XYvRd7oD')
response.headers['content-type']
response.reason


state = response.request
state.method
state.path_url
# Out:
# '/v1/images/0XYvRd7oD'

# %%
catImage = requests.get('https://api.thecatapi.com/v1/images/0XYvRd7oD')

## Check the conent
catImage.text
catImage.content
catImage.headers
catImage.method

## Check the status 
catImage.status_code
catImage.reason

## To get extra url information on the GET
state = catImage.request
state.method
state.path_url
state.url
state.headers
# Out:
# 'Not Found'

# %% [markdown]
# Headers and content type

# %%
## Headers

headResponse = requests.get("https://api.thecatapi.com/v1/breeds/abys")

# To inspect the header
headResponse.request.headers

# Check the Conent type
headResponse.headers.get("Content-Type")

imageApi = requests.get('https://image-charts.com/chart?chs=700x125&cht=ls&chd=t:23,15,28')
imageApi.status_code
imageApi.request.headers
imageApi.headers.get('Content-Type')

# Storing item picture in a file
with open("chart.png", mode = "wb") as file:
  file.write(imageApi.content)
# Out:
# 'image/png'

# %% [markdown]
# Response Content and filtering content

# %%
import requests
import pandas as pd
import json
from pandas import json_normalize

CatRespCont = requests.get("https://api.thecatapi.com/v1/breeds/abys")

CatRespCont.request.headers
CatRespCont.headers.get('Content-Type')

#Return in json format
CatRespCont.json()

# %% [markdown]
# Query Parameter

# %%
import requests

# Random outputs
queryImport = requests.get("https://randomuser.me/api/").json()

# Generate only female 
queryImport = requests.get("https://randomuser.me/api/?gender ?gender = female").json()

# Generate only female users from Germany
queryImport = requests.get("https://randomuser.me/api/?gender=female&nat=de").json()

queryImport

# %% [markdown]
# Using params to query

# %%
query_params = {"gender":"female", "nat": "de"}
requests.get("https://randomuser.me/api/", params=query_params).json()
# Out:
# {'results': [{'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Sigrid', 'last': 'Lindemann'},
#    'location': {'street': {'number': 2400, 'name': 'Parkstraße'},
#     'city': 'Gütersloh',
#     'state': 'Sachsen',
#     'country': 'Germany',
#     'postcode': 74338,
#     'coordinates': {'latitude': '-41.6741', 'longitude': '131.5797'},
#     'timezone': {'offset': '-9:00', 'description': 'Alaska'}},
#    'email': 'sigrid.lindemann@example.com',
#    'login': {'uuid': '8413b5cb-4b8b-44a4-a36f-65eef87d91ff',
#     'username': 'greenzebra477',
#     'password': 'catfish',
#     'salt': 'pRGUqPqk',
#     'md5': '7e2ce4316fdbe3d16a978096e1a78b21',
#     'sha1': 'fb68ea8bf09c5ed03b34cc7594b8be480b76eb42',
#     'sha256': '482c372a74116b872a6f1e8e20e0af8ecc80d88f801fc67de9a1657ca29951b4'},
#    'dob': {'date': '1964-09-08T13:36:50.585Z', 'age': 59},
#    'registered': {'date': '2021-02-05T17:56:16.203Z', 'age': 2},
#    'phone': '0954-8509902',
#    'cell': '0172-0719455',
#    'id': {'name': 'SVNR', 'value': '72 080964 L 911'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/90.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/90.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/90.jpg'},
#    'nat': 'DE'}],
#  'info': {'seed': 'f3c0534d0feeb457',
#   'results': 1,
#   'page': 1,
#   'version': '1.4'}}

# %% [markdown]
# ## Practise with Reallife API

# %% [markdown]
# Youtube API for Python: How to Create a Unique Data Portfolio Project   <br>
# https://www.youtube.com/watch?v=D56_Cx36oGY

# %%
# Get Your API from a json file
import json
with open(r"C:\Users\orena\OneDrive\01_ORENAIKE\02_CAREER_AND_DEVELOPMENTS\01_Schools\ALX\Codes\APIs\Api.json") as f:
  data = json.load(f)
  api_key = data["YoutubeApi_Key"]
  
  # Channel IDs
  channel_ids = ['UCoOae5nYA7VqaXzerajD0lg']

# %%
import os

from googleapiclient.discovery import build
import json
from IPython.display import JSON

# import google_auth_oauthlib.flow
# import googleapiclient.discovery
# import googleapiclient.errors

# scopes = ["https://www.googleapis.com/auth/youtube.readonly"]#

api_service_name = "youtube"
api_version = "v3"

youtube = build(api_service_name, api_version, developerKey = api_key)

request = youtube.channels().list(
    part = "snippet,contentDetails,statistics",
    id = ",".join(channel_ids)
)

response = request.execute()
JSON(response)
# print(response)

# %% [markdown]
# ## Google API v2
#
# Link to Resource: https://www.youtube.com/watch?v=fklHBWow8vE
#
# Consumming API that requires Token

# %%
# Get Your API from a json file
import json
with open(r"C:\Users\orena\OneDrive\01_ORENAIKE\02_CAREER_AND_DEVELOPMENTS\01_Schools\ALX\Codes\APIs\Api.json") as f:
  data = json.load(f)
  api_key = data["YoutubeApi_Key"]
  
  # Channel IDs
  channel_ids = ['UCoOae5nYA7VqaXzerajD0lg']

# %%
# giphy_trending.py


# url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY


# id&order=date&maxResults=1000

import requests
#from googleapiclient.discovery import build
import json
from IPython.display import JSON

# Build the parameter
API_KEY = api_key
endpoint = "https://www.googleapis.com/youtube/v3/search"
video_id = "UC2UXDak6o7rBm23k3Vv5dww"

# UCoOae5nYA7VqaXzerajD0lg

# Parameters for the API request
params = {
    "id": video_id,
    "part": "snippet",
    "chart": "mostPopular",
    "regionCode": "US",
    "key": API_KEY,
    "maxResults": 50,  # Set to the maximum allowed value
    "order": "date"    # Order by date
}

response = requests.get(endpoint, params=params).json()
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        videoid = video['id']['videoId']
        video_title = video['snippet']['title']
        publishDate = video['snippet']['publishedAt']
        publishDate = str(publishDate).split("T")[0]

        print(videoid)
        print(video_title)
        print(publishDate)
# Out:
# o3gufVRMXtQ
# LIVE | Big Decision Against Imran Khan | Latif Khosa&#39;s Important Press Conference | Capital TV
# 2023-11-17
# Cincinnati Bengals vs. Baltimore Ravens | 2023 Week 11 Game Highlights
# 2023-11-17
# 7fPQQIVHxbE
# THIS IS THE FASTEST HOT WHEELS DRAG RACE! 😱 500+ KMPH! - Forza Horizon 5 | LOGITECH G29
# 2023-11-17
# iDgJPkOSlws
# அமைச்சர் செந்தில் பாலாஜி பித்தப்பையில் கல் | Senthil Balaji | ED | TN Govt
# 2023-11-17
# KmcKzVr6_5g
# Anand Ranganathan Ji Shocked | #Exmuslim
# 2023-11-17
# 3-iSLMTw2SI
# Bhabhi Gayi 5 Lakh Ke Competition Mei 🫣💃🏻 #neetubisht #comedy #trendingonshorts #nanandbhabhi
# 2023-11-17
# IPFkz6AlTvw
# 逾六成企業發年終 比例低於去年 臭蟲在台!有錢人的家是溫床 | 十點不一樣 20231116
# 2023-11-17
# AgfDDG9K8Uo
# Alone Enough To Clutch Every Squad 😱 #shortsfeed #tgrnrz #freefire
# 2023-11-17
# 0IrVSkHQbOM
# Check Out Milwaukee’s’ Cordless Tire Inflator
# 2023-11-17

# %% [markdown]
# ## Get Video Details

# %%
# Get Your API from a json file
import json
with open(r"C:\Users\orena\OneDrive\01_ORENAIKE\02_CAREER_AND_DEVELOPMENTS\01_Schools\ALX\Codes\APIs\Api.json") as f:
  data = json.load(f)
  api_key = data["YoutubeApi_Key"]
  
  # Channel IDs
  channel_ids = ['UCoOae5nYA7VqaXzerajD0lg']

# %%
import requests

url_video_stats = "https://www.googleapis.com/youtube/v3/videos"


# Parameters for the Video details API
vidDetailsParams = {
    #"id": video_id,
    "part": "statistics",
    "chart": "mostPopular",
    "regionCode": "US",
    "key": api_key,
    "maxResults": 50,  # Set to the maximum allowed value
    # "order": "date"    # Order by date
}

vidDetailsParams = requests.get(url_video_stats, params=vidDetailsParams).json()
vidDetailsParams


# for video in response['items']:
#     if video['id']['kind'] == 'youtube#video':
#         videoid = video['id']['videoId']
#         video_title = video['snippet']['title']
#         publishDate = video['snippet']['publishedAt']
#         publishDate = str(publishDate).split("T")[0]

#         print(videoid)
#         print(video_title)
#         print(publishDate)
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'tLEQyfAT5ZsGSm6HVFISlQr3kgw',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'FMuuaZ0pq_nSZRTU9OBdPGj4wEQ',
#    'id': 'jsI3mgcLJZA',
#    'statistics': {'viewCount': '5652129',
#     'likeCount': '84927',
#     'favoriteCount': '0',
#     'commentCount': '8504'}},
#   {'kind': 'youtube#video',
#    'etag': 'OF8DZgRGFMrHin5a9TMLzQm9-7E',
#    'id': 'Xty2gi5cMa8',
#    'statistics': {'viewCount': '5503907',
#     'likeCount': '467182',
#     'favoriteCount': '0',
#     'commentCount': '1495'}},
#   {'kind': 'youtube#video',
#    'etag': 'rHgne7GWtvz3XT55iDxeRL0b64U',
#    'id': '2ow9mZkZa8o',
#    'statistics': {'viewCount': '585583',
#     'likeCount': '7862',
#     'favoriteCount': '0',
#     'commentCount': '461'}},
#   {'kind': 'youtube#video',
#    'etag': 'ixEJMXz8dy0Osi2RgBddLJdNAPo',
#    'id': '0JYqz9yEn78',
#    'statistics': {'viewCount': '323110',
#     'likeCount': '11237',
#     'favoriteCount': '0',
#     'commentCount': '1809'}},
#   {'kind': 'youtube#video',
#    'etag': 'BiFnCGL8st0etoScLawinfX3xvs',
#    'id': 'wrhDUwYbTkI',
#    'statistics': {'viewCount': '607683',
#     'likeCount': '38168',
#     'favoriteCount': '0',
#     'commentCount': '3128'}},
#   {'kind': 'youtube#video',
#    'etag': 'hiDrHe2UZtoa85KIAkinBkm4_54',
#    'id': 'YXt0Nw8xWh0',
#    'statistics': {'viewCount': '910383',
#     'likeCount': '73589',
#     'favoriteCount': '0',
#     'commentCount': '3419'}},
#   {'kind': 'youtube#video',
#    'etag': 'bhA34SQOvCxheBPzP_eiGWmNDT8',
#    'id': 'M49i6CFPMmk',
#    'statistics': {'viewCount': '1070520',
#     'likeCount': '46807',
#     'favoriteCount': '0',
#     'commentCount': '1992'}},
#   {'kind': 'youtube#video',
#    'etag': 'nn8PWPgKoUo0LM9sk43vlIqdj1g',
#    'id': 't65DWjWmAzo',
#    'statistics': {'viewCount': '242121',
#     'likeCount': '2352',
#     'favoriteCount': '0',
#     'commentCount': '1681'}},
#   {'kind': 'youtube#video',
#    'etag': 'HMZDfpgylSQEPFrYEgfTplCFKIk',
#    'id': '5uBa5rrUifM',
#    'statistics': {'viewCount': '1211526',
#     'likeCount': '75153',
#     'favoriteCount': '0',
#     'commentCount': '2969'}},
#   {'kind': 'youtube#video',
#    'etag': 'hiq0USlQ4XwFfIdwjAMJ_SPO1eA',
#    'id': 'OKDahK8USV4',
#    'statistics': {'viewCount': '191217',
#     'likeCount': '3652',
#     'favoriteCount': '0',
#     'commentCount': '617'}},
#   {'kind': 'youtube#video',
#    'etag': 'd8CdOHvBy9qabYMYeICWGc8hjE4',
#    'id': 's_76M4c4LTo',
#    'statistics': {'viewCount': '12227075',
#     'likeCount': '79432',
#     'favoriteCount': '0',
#     'commentCount': '16676'}},
#   {'kind': 'youtube#video',
#    'etag': 'DWwsXoW8CaghPmTQhT4rtCbZF-g',
#    'id': 'KKjIqCVFUyM',
#    'statistics': {'viewCount': '1074746',
#     'likeCount': '68689',
#     'favoriteCount': '0',
#     'commentCount': '2501'}},
#   {'kind': 'youtube#video',
#    'etag': 'P2zkzOgQCf9OMLzW_vUQO7jsXlI',
#    'id': 'BDpDV1Qxfik',
#    'statistics': {'viewCount': '134045',
#     'likeCount': '14566',
#     'favoriteCount': '0',
#     'commentCount': '1593'}},
#   {'kind': 'youtube#video',
#    'etag': 'DFY9eRXvsfkSF5sRBag6kCQEaWo',
#    'id': 'A6Z9gkJnfgw',
#    'statistics': {'viewCount': '1383109',
#     'likeCount': '99080',
#     'favoriteCount': '0',
#     'commentCount': '6316'}},
#   {'kind': 'youtube#video',
#    'etag': 'i4eOIHgv_9FJ6Y5JZfj8rwEFErw',
#    'id': 'uHb7au6Gmls',
#    'statistics': {'viewCount': '2968766',
#     'likeCount': '70685',
#     'favoriteCount': '0',
#     'commentCount': '4647'}},
#   {'kind': 'youtube#video',
#    'etag': 'C5vl9YusCVUVr9lLGm3ENvD4zBs',
#    'id': 'geUMkoM42iE',
#    'statistics': {'viewCount': '434938',
#     'likeCount': '7713',
#     'favoriteCount': '0',
#     'commentCount': '1019'}},
#   {'kind': 'youtube#video',
#    'etag': 'QdLUHeAP-IFNFv5mNGjNQHPUfYE',
#    'id': '6KP843X-Qys',
#    'statistics': {'viewCount': '526986',
#     'likeCount': '55796',
#     'favoriteCount': '0',
#     'commentCount': '2207'}},
#   {'kind': 'youtube#video',
#    'etag': 'VwKZqWKu6HfosqBFnPsgcwntKMY',
#    'id': 'JGY71JdCny4',
#    'statistics': {'viewCount': '487911',
#     'likeCount': '47207',
#     'favoriteCount': '0',
#     'commentCount': '1762'}},
#   {'kind': 'youtube#video',
#    'etag': 'I6IihPQXHC2TiQ2b2nDHi0Y0kLk',
#    'id': 'lDGmSCXoSRs',
#    'statistics': {'viewCount': '755104',
#     'likeCount': '44773',
#     'favoriteCount': '0',
#     'commentCount': '2796'}},
#   {'kind': 'youtube#video',
#    'etag': '6e8_vwgJnJEHFw4jU1eBkFEemIA',
#    'id': '-_HIZtRlkDo',
#    'statistics': {'viewCount': '455179',
#     'likeCount': '28117',
#     'favoriteCount': '0',
#     'commentCount': '2106'}},
#   {'kind': 'youtube#video',
#    'etag': 'N0IS46nnxu6Qr8zZE0b_79At7kc',
#    'id': 'wYdAs5yhmhk',
#    'statistics': {'viewCount': '3809332',
#     'favoriteCount': '0',
#     'commentCount': '7013'}},
#   {'kind': 'youtube#video',
#    'etag': 'qALGMtvnQjr292UoetvcXPiHqkY',
#    'id': 'aQXD-Wr6h64',
#    'statistics': {'viewCount': '706118',
#     'likeCount': '25152',
#     'favoriteCount': '0',
#     'commentCount': '2068'}},
#   {'kind': 'youtube#video',
#    'etag': 'Dom4wepJMgxS2alsRz7WTFX5xb8',
#    'id': 'koSxGPCXQKI',
#    'statistics': {'viewCount': '116484',
#     'likeCount': '10824',
#     'favoriteCount': '0',
#     'commentCount': '575'}},
#   {'kind': 'youtube#video',
#    'etag': 'dSbS8hhMV5f7kVLdSwgGQylvavs',
#    'id': '2UZ-AhV4T60',
#    'statistics': {'viewCount': '168945',
#     'likeCount': '11764',
#     'favoriteCount': '0',
#     'commentCount': '824'}},
#   {'kind': 'youtube#video',
#    'etag': 'MqGZFWX0_MEljaF1m2NFB07UdTg',
#    'id': 'qfBBc_Go0QA',
#    'statistics': {'viewCount': '397942',
#     'likeCount': '16682',
#     'favoriteCount': '0',
#     'commentCount': '957'}},
#   {'kind': 'youtube#video',
#    'etag': 'oUTLYWoCEbGqk6YP0mBjsTx1TV4',
#    'id': 'uA6f1IoUKs0',
#    'statistics': {'viewCount': '7753791',
#     'likeCount': '111147',
#     'favoriteCount': '0',
#     'commentCount': '10513'}},
#   {'kind': 'youtube#video',
#    'etag': 'MTGVdrzjU7-j_PC3FAsuiarEWkg',
#    'id': 'v11dHZZq5yk',
#    'statistics': {'viewCount': '932360',
#     'likeCount': '68287',
#     'favoriteCount': '0',
#     'commentCount': '7687'}},
#   {'kind': 'youtube#video',
#    'etag': 'OzCdSlySw3Jv9BXYZDhHVwwa4-g',
#    'id': 'NacTCPmfDEM',
#    'statistics': {'viewCount': '794715',
#     'likeCount': '68776',
#     'favoriteCount': '0',
#     'commentCount': '4937'}},
#   {'kind': 'youtube#video',
#    'etag': 'D-YTULMU6lOK5VZd6VMVgEJSlbU',
#    'id': 'mckLX1Up0kM',
#    'statistics': {'viewCount': '315925',
#     'likeCount': '1107',
#     'favoriteCount': '0',
#     'commentCount': '111'}},
#   {'kind': 'youtube#video',
#    'etag': 'meXRmMY_Ku_ybpGKyWZlKTJpWbc',
#    'id': 'TiEVqZ2Bc_c',
#    'statistics': {'viewCount': '5511537',
#     'likeCount': '263749',
#     'favoriteCount': '0',
#     'commentCount': '9657'}},
#   {'kind': 'youtube#video',
#    'etag': 'z5X0e1pHPBK_EXnF78CV50_bjgA',
#    'id': '1_VHfcpNcPA',
#    'statistics': {'viewCount': '590048',
#     'likeCount': '42492',
#     'favoriteCount': '0',
#     'commentCount': '4045'}},
#   {'kind': 'youtube#video',
#    'etag': 'QfO7hUGm7eT-rkK-eZPBLypd9YM',
#    'id': 'aj2LKDT767Y',
#    'statistics': {'viewCount': '1919929',
#     'likeCount': '109633',
#     'favoriteCount': '0',
#     'commentCount': '7542'}},
#   {'kind': 'youtube#video',
#    'etag': 'WmlZTkjAcvs7T4xZz2lCr6pYm8U',
#    'id': 'PjgJWIA46rA',
#    'statistics': {'viewCount': '309004',
#     'likeCount': '8811',
#     'favoriteCount': '0',
#     'commentCount': '517'}},
#   {'kind': 'youtube#video',
#    'etag': 'Ygs7cuLKZ9ESGwB5Zsyoexlg_Rk',
#    'id': 'NhKBk9Qv78k',
#    'statistics': {'viewCount': '189571',
#     'likeCount': '1527',
#     'favoriteCount': '0',
#     'commentCount': '369'}},
#   {'kind': 'youtube#video',
#    'etag': 'dgdCpJjkIQKY6otVaCUFeqHjvvA',
#    'id': 'eBHdstSYy28',
#    'statistics': {'viewCount': '125759',
#     'likeCount': '10637',
#     'favoriteCount': '0',
#     'commentCount': '743'}},
#   {'kind': 'youtube#video',
#    'etag': 'hKFavDG49nySX_NT-KWs7znf1q0',
#    'id': '5kzP7ZNHPes',
#    'statistics': {'viewCount': '646556',
#     'likeCount': '55008',
#     'favoriteCount': '0',
#     'commentCount': '3595'}},
#   {'kind': 'youtube#video',
#    'etag': 'olkRva5-LU1MzmdbK_ZKN4jSX0U',
#    'id': 'ZZgW0vOvJOs',
#    'statistics': {'viewCount': '690511',
#     'likeCount': '25396',
#     'favoriteCount': '0',
#     'commentCount': '1073'}},
#   {'kind': 'youtube#video',
#    'etag': '07JoSLtIo33Ob8Gl90Z-Xw6lsWA',
#    'id': 'Rl-Okv32Cg0',
#    'statistics': {'viewCount': '1583834',
#     'likeCount': '140303',
#     'favoriteCount': '0',
#     'commentCount': '9860'}},
#   {'kind': 'youtube#video',
#    'etag': 'xMG_5KY2GhGCg2qEx6mCQgAZtPY',
#    'id': '_PG_pNnvk5o',
#    'statistics': {'viewCount': '2832604',
#     'likeCount': '193723',
#     'favoriteCount': '0',
#     'commentCount': '59200'}},
#   {'kind': 'youtube#video',
#    'etag': 'V26OzhBJRtTdHXCqNac5jccuUeQ',
#    'id': 'JxJyI8AoReY',
#    'statistics': {'viewCount': '740174',
#     'likeCount': '15661',
#     'favoriteCount': '0',
#     'commentCount': '398'}},
#   {'kind': 'youtube#video',
#    'etag': 'YB9Hlo2rQMWFR-mtDhGFo77PH5c',
#    'id': 'cs_6GCuz1I4',
#    'statistics': {'viewCount': '503299',
#     'likeCount': '27663',
#     'favoriteCount': '0',
#     'commentCount': '827'}},
#   {'kind': 'youtube#video',
#    'etag': '1RJElbItYYbg8GXDCSppmUX0gFo',
#    'id': 'tybKnGZRwcU',
#    'statistics': {'viewCount': '3171594',
#     'likeCount': '167061',
#     'favoriteCount': '0',
#     'commentCount': '9092'}},
#   {'kind': 'youtube#video',
#    'etag': 'PwnjaNQRvGGhI1mnfefwx0n08xc',
#    'id': '0WTGmmlVFEY',
#    'statistics': {'viewCount': '428582',
#     'likeCount': '15682',
#     'favoriteCount': '0',
#     'commentCount': '1426'}},
#   {'kind': 'youtube#video',
#    'etag': 'r5aRMQfMk77lzUTEuJzlwVgW-DM',
#    'id': 'vREokZa4dNU',
#    'statistics': {'viewCount': '503045',
#     'likeCount': '57054',
#     'favoriteCount': '0',
#     'commentCount': '3021'}},
#   {'kind': 'youtube#video',
#    'etag': 'D4ZgklVBHXrtmHHdUSBWhb6B51U',
#    'id': 'RI_WrM-zrxg',
#    'statistics': {'viewCount': '762900',
#     'likeCount': '69007',
#     'favoriteCount': '0',
#     'commentCount': '6218'}},
#   {'kind': 'youtube#video',
#    'etag': 'jzqysZGZTMj5H3D_iJbwpiiflvA',
#    'id': 'oV0Yf2Sn1DU',
#    'statistics': {'viewCount': '712529',
#     'likeCount': '49291',
#     'favoriteCount': '0',
#     'commentCount': '2900'}},
#   {'kind': 'youtube#video',
#    'etag': 'jD0s9ElV4XGnTRQ1u6_zoqAxCb8',
#    'id': 'ftpH4-xFGQI',
#    'statistics': {'viewCount': '478335',
#     'likeCount': '19338',
#     'favoriteCount': '0',
#     'commentCount': '1000'}},
#   {'kind': 'youtube#video',
#    'etag': '3vYlsvDoUDEJUOUaTFgcGIX_grc',
#    'id': 'So8hqTBHXrc',
#    'statistics': {'viewCount': '491683',
#     'likeCount': '24471',
#     'favoriteCount': '0',
#     'commentCount': '2014'}},
#   {'kind': 'youtube#video',
#    'etag': 'SJYyGSz2ziztlgA4yyFbkWmV61M',
#    'id': 'bKjENaF0ZrI',
#    'statistics': {'viewCount': '403831',
#     'likeCount': '12043',
#     'favoriteCount': '0',
#     'commentCount': '5510'}},
#   {'kind': 'youtube#video',
#    'etag': 'VCAzqZ5X-ctRGJctWi8UxFUbiSM',
#    'id': 'MPQmPcUFZXk',
#    'statistics': {'viewCount': '226575',
#     'likeCount': '19265',
#     'favoriteCount': '0',
#     'commentCount': '967'}}],
#  'nextPageToken': 'CDIQAA',
#  'pageInfo': {'totalResults': 200, 'resultsPerPage': 50}}

# %%
import pandas
# response['items'][0]['id']['videoId']
response['items'][0]['snippet']['title']

publishDate = video['snippet']['publishedAt']
publishDate = str(publishDate).split("T")[0]
publishDate
# Out:
# '2023-11-17'

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        videoid = video['id']['videoId']
        video_title = video['snippet']['title']
        publishDate = video['snippet']['publishedAt']
        publishDate = str(publishDate).split("T")[0]

        url_video_stats = "https://www.googleapis.com/youtube/v3/videos"

        print(videoid)
        print(video_title)
        print(publishDate)
# Out:
# HVB4r6Z-B8U
# 🔴Live : Union Minister Narendra Singh Tomar की विधासनभा सीट दिमनी में हो गया बड़ा कांड | Breaking
# 2023-11-17
# 9gDO-I-3mxQ
# ঘূর্ণিঝড় &#39;মিধিলি: ৩ শতাধিক জেলেসহ ২০টি ট্রলার নিখোঁজ | Cyclone &#39;Midhili&#39; | Rtv News
# 2023-11-17
# QkBiE8xuig4
# Israel-Hamas war: IDF discovers booby-trapped car with huge weapons cache in Al-Shifa Hospital
# 2023-11-17
# CG3EHorAWuo
# Утренний разворот. Новый кандидат в президенты России. Венедиктов*, Баблоян и Воробьёва / 17.11.23
# 2023-11-17
# nZXMNzn1zOY
# ９９％が苦戦するラスボスを３分で倒す方法が賢いけどセコすぎる『 Ark: Survival Evolved 』#60
# 2023-11-17
# 74_wjkv7QY4
# Dramatische Verfolgungsjagd: Polizei rammt BMW
# 2023-11-17
# 0TBpEOhJscE
# Ebru Baki ile Para Politika 17 Kasım
# 2023-11-17
# w6vnEElnTlA
# Yatnal | ಯತ್ನಾಳ್ ಮನೆಗೆ ಬಂದಿದ್ಯಾರು? | BJP State President BY Vijayendra | N18V
# 2023-11-17
# vadJ2GaISeo
# Abdul kabeer ke sath racing laga li heavy bike per 😂🏍️ Kon jeeta phir ?
# 2023-11-17
# 2EuGm-wHkrY
# Uttarkashi Tunnel Collapse: 40 मजदूरों को बचाने की जंग, Drilling के दौरान आई परेशानी| वनइंडिया हिंदी
# 2023-11-17
# CYgjF2y7zJQ
# That look from Manuel Neuer! 🥶
# 2023-11-17
# H5isxAGEn_o
# PUTINS KRIEG: Experte verrät! &quot;Erfolgreich russische Schiffe angegriffen&quot; Aber Bedrohung bleibt hoch
# 2023-11-17
# Obp4VTXubT0
# Gopichand Padalkar On  Chhagan Bhujbal :OBC चा ढाण्या वाघ म्हणून छगन भुजबळ याचं पडळकरांकडून अभिनंदन
# 2023-11-17
# AazxDk1ODVo
# Kenny Veach Vanishes on his Quest for the M Cave | Mojave Mysteries Vol. 1
# 2023-11-17
# 27hacOl7kaQ
# Ozuna, Lito MC Cassidy - SM (Visualizer Oficial) | COSMO
# 2023-11-17
# kyPp04ftMF4
# What Would Pluto Do
# 2023-11-17
# rlLpDqJnakU
# India Vs Australia या WorldCup Final मध्ये कोणती टीम कोणाला जड जाईल ? आकडे काय सांगतात ?
# 2023-11-17
# hqdyB5k1sJI
# Qing Madi - Vision (Official Lyric Video)
# 2023-11-17
# koSxGPCXQKI
# 42 Dugg - SpinDatBac (Official Audio)
# 2023-11-17
# nIRe5zmdQ8Y
# MP Election 2023 : Germany से वोट डालने पहुंची युवती ने क्या कहा ज़रुर सुनिए ? | BJP| Congress |
# 2023-11-17
# cYg4vgg5Msg
# MP-CG Election 2023: MP-Chhattisgarh में अब तक कितने फीसदी मतदान ? Shivraj | Kamalnath | Breaking
# 2023-11-17
# QYPQqivWHWc
# ESL One Kuala Lumpur - SA Closed Qualifier - Day 1 - Stream A
# 2023-11-17
# oc2WppiK1NY
# LIVE : कुलगाम में बड़ा एनकाउंटर, घिर गए पाँच आतंकी| Jammu Kashmir Encounter | Hindi News | Pakistan
# 2023-11-17
# bjG3O77imXM
# CALIENTE derrota ARGENTINA; MESSI EXPLOTA | LUIS DIAZ héroe y VINI out | “ESPAÑA el MEJOR del MUNDO”
# 2023-11-17
# nVXVSYckSmM
# 100 Personil Tim SAR Gabungan Diterjunkan ke Lokasi Jatuhnya Pesawat Latih Super Tucano | Liputan6
# 2023-11-17
# a7giSb3drl4
# Team Plan and updates for today Ahmedabad
# 2023-11-17
# T1VFwMJBuD0
# 15 Years all for nothing...
# 2023-11-17
# zQGn3VpJ-wA
# Adorable Toddler Rocks Puppy to Sleep!
# 2023-11-17
# a5LoLEM0EcY
# CHOTU DADA KA KHACHCHAR | छोटू दादा का खच्चर | Khandesh Hindi Comedy | Chotu Dada New Comedy 2023
# 2023-11-17
# 8KMN0MUmiYo
# मोर MOR Part-2 | Uttar kumar New movie  2023 | Jyoti Mathur | Rajlaxmi
# 2023-11-17

# %%
video_title
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 video_title
#
# NameError: name 'video_title' is not defined

# %%
import requests

# Replace with your API key
API_KEY = "YOUR_API_KEY_HERE"

# Add a video_id variable (set this to the desired video ID)
video_id = "VIDEO_ID_HERE"

# Endpoint for the YouTube Data API
endpoint = "https://www.googleapis.com/youtube/v3/videos"


# Parameters for the API request
params = {
    "id": video_id,
    "part": "statistics",
    "key": API_KEY
}

# Make the request and get the response
response = requests.get(endpoint, params=params).json()

# Print or process the response
print(response)


params = {"key": API_KEY, "part": "snippet", "chart": "mostPopular", "regionCode": "US"}
response = requests.get(endpoint, params=params)

# %%
import requests
import pandas as pd

# %%
# Get Your API from a json file
import json
with open(r"C:\Users\orena\OneDrive\01_ORENAIKE\02_CAREER_AND_DEVELOPMENTS\01_Schools\ALX\Codes\APIs\Api.json") as f:
  data = json.load(f)
  api_key = data["YoutubeApi_Key"]
  
  # Channel IDs
  channel_ids = ['UCoOae5nYA7VqaXzerajD0lg']

# %%
api_key
