# %% [markdown]
# ## Get Your API

# %%
# Get Your API from a json file
import json
with open(r"C:\Users\orena\OneDrive\01_ORENAIKE\02_CAREER_AND_DEVELOPMENTS\01_Schools\ALX\Codes\APIs\Api.json") as f:
  data = json.load(f)
  api_key = data["YoutubeApi_Key"]
  
  # Channel IDs
  channel_ids = ['UCoOae5nYA7VqaXzerajD0lg']

# %% [markdown]
# ## Write a function to get trending videos

# %%
import requests
import json

# Function to get trending videos
def get_trending_videos(api_key, region_code='US', max_results=50):
    endpoint = "https://www.googleapis.com/youtube/v3/videos"
    
    params = {
        "part": "snippet,statistics",  # Get snippet and statistics data
        "chart": "mostPopular",        # Fetch most popular videos
        "regionCode": region_code,     # Region code, e.g., US
        "key": api_key,
        "maxResults": max_results      # Maximum results per request
    }

    response = requests.get(endpoint, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        return None
    
# Fetch trending videos
trending_videos = get_trending_videos(api_key)
trending_videos
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'IMnGi-nLHx0XU14quKJkw5ejaXI',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'di6__O5QnYXL4HaLL5QRhgW7ZCY',
#    'id': 'Xty2gi5cMa8',
#    'snippet': {'publishedAt': '2023-11-15T20:26:07Z',
#     'channelId': 'UCByOQJjav0CUDwxCk-jVNRQ',
#     'title': 'Drake - First Person Shooter ft. J Cole',
# ...

# %%
# # # Replace 'YOUR_API_KEY' with your actual YouTube Data API key
# # api_key = 'YOUR_API_KEY'

# # Fetch trending videos
# trending_videos = get_trending_videos(api_key)

# Process and display the results
if trending_videos:
    for video in trending_videos['items']:
        video_id = video['id']
        video_title = video['snippet']['title']
        publish_date = video['snippet']['publishedAt'].split("T")[0]

        print(video_id)
        print(video_title)
        print(publish_date)
# Out:
# Xty2gi5cMa8
# Drake - First Person Shooter ft. J Cole
# 2023-11-15
# s_76M4c4LTo
# MADAME WEB – Official Trailer (HD)
# 2023-11-15
# uHb7au6Gmls
# Percy Jackson and The Olympians | Official Trailer | Disney+
# 2023-11-16
# lDGmSCXoSRs
# André 3000 Talks His New Album and Life After Outkast | GQ
# 2023-11-16
# uA6f1IoUKs0
# 72nd MISS UNIVERSE Preliminary Competition
# 2023-11-16
# v11dHZZq5yk
# Luar La L x Custom - La Purga
# 2023-11-16
# TiEVqZ2Bc_c
# Marvel Studios’ What If…? Season 2 | Official Trailer | Disney+
# 2023-11-15
# 1_VHfcpNcPA
# EXPLAINING The Starter Pokemon Battle Royale from @TerminalMontage! 💥
# 2023-11-15
# aj2LKDT767Y
# Secret Tunnel/Garage Update #4
# 2023-11-16
# PjgJWIA46rA
# The End of NFL Man | Hot Mess with Alix Earle
# 2023-11-16
# Rl-Okv32Cg0
# Starter Pokemon Battle Royale 💥 Collab With @Gnoggin
# 2023-11-15
# ZZgW0vOvJOs
# I Made YOUR Drawings into MINECRAFT Mobs!
# 2023-11-16
# _PG_pNnvk5o
# rest in peace, bosley.
# 2023-11-15
# oV0Yf2Sn1DU
# I'm Back!
# ...

# %%
# Get Your API from a json file
import json
with open(r"C:\Users\orena\OneDrive\01_ORENAIKE\02_CAREER_AND_DEVELOPMENTS\01_Schools\ALX\Codes\APIs\Api.json") as f:
  data = json.load(f)
  api_key = data["YoutubeApi_Key"]

# %%
import requests
import pandas as pd

# API Key and endpoint
api_key = api_key
endpoint = "https://www.googleapis.com/youtube/v3/videos"
channel_id = ['UCoOae5nYA7VqaXzerajD0lg']

# Parameters for the API request to get trending videos
params = {
    "part": "snippet,statistics",
    "chart": "mostPopular",
    "regionCode": "US",
    "key": api_key,
    "maxResults": 50,
    "channelId": channel_id,
}

# Fetch trending videos
response = requests.get(endpoint, params=params).json()

# Create an empty DataFrame
df = pd.DataFrame(columns=["videoId", "title", "publishDate", "viewCount", "likeCount", "commentCount"])

# Process each video
for video in response['items']:
    video_id = video['id']
    title = video['snippet']['title']
    publish_date = video['snippet']['publishedAt'].split("T")[0]
    view_count = video['statistics'].get('viewCount')
    like_count = video['statistics'].get('likeCount')
    comment_count = video['statistics'].get('commentCount')

    # Append to DataFrame
    data = []
    for video in response['items']:
        data.append({
            "videoId": video_id,
            "title": title,
            "publishDate": publish_date,
            "viewCount": view_count,
            "likeCount": like_count,
            "channelId": channel_id,
            "commentCount": comment_count
        })

# Create DataFrame from the accumulated data
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#         videoId                                              title  \
# 0   MPQmPcUFZXk  The Most Important Go-Kart Revival Ever Filmed...
# 1   MPQmPcUFZXk  The Most Important Go-Kart Revival Ever Filmed...
# 2   MPQmPcUFZXk  The Most Important Go-Kart Revival Ever Filmed...
# 3   MPQmPcUFZXk  The Most Important Go-Kart Revival Ever Filmed...
# 4   MPQmPcUFZXk  The Most Important Go-Kart Revival Ever Filmed...
# 5   MPQmPcUFZXk  The Most Important Go-Kart Revival Ever Filmed...
# 6   MPQmPcUFZXk  The Most Important Go-Kart Revival Ever Filmed...
# 7   MPQmPcUFZXk  The Most Important Go-Kart Revival Ever Filmed...
# 8   MPQmPcUFZXk  The Most Important Go-Kart Revival Ever Filmed...
# 9   MPQmPcUFZXk  The Most Important Go-Kart Revival Ever Filmed...
# 10  MPQmPcUFZXk  The Most Important Go-Kart Revival Ever Filmed...
# 11  MPQmPcUFZXk  The Most Important Go-Kart Revival Ever Filmed...
# 12  MPQmPcUFZXk  The Most Important Go-Kart Revival Ever Filmed...
# ...

# %%
import json

# Fetch trending videos
response = requests.get(endpoint, params=params).json()

# Print the entire response to inspect its structure
print(json.dumps(response, indent=4))

# Check if 'items' key exists in the response
if 'items' in response:
    # Existing code to process each video
    ...
else:
    print("No 'items' key in the response. Here's the response:", response)
# Out:
# {
#     "error": {
#         "code": 400,
#         "message": "API key not valid. Please pass a valid API key.",
#         "errors": [
#             {
#                 "message": "API key not valid. Please pass a valid API key.",
#                 "domain": "global",
#                 "reason": "badRequest"
#             }
#         ],
#         "status": "INVALID_ARGUMENT",
#         "details": [
#             {
#                 "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#                 "reason": "API_KEY_INVALID",
#                 "domain": "googleapis.com",
#                 "metadata": {
#                     "service": "youtube.googleapis.com"
#                 }
#             }
#         ]
#     }
# }
# ...
