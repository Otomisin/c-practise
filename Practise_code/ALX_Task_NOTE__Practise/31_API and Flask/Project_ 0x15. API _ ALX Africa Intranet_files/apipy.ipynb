# %%
import requests
import json

reponse = requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")

# print(reponse.json()['items'])
for data in reponse.json()['items']:
    if data['answer_count'] == 0:
      print(data['title'])
      print(data['link'])
    else:
      print("skipped")
    print()
# Out:
# skipped
#
# I&#39;m at my wits end to make my ESP32 capture keypresses and send it over serial. Any tips?
# https://stackoverflow.com/questions/76910671/im-at-my-wits-end-to-make-my-esp32-capture-keypresses-and-send-it-over-serial
#
# How to track and change the state of an elements useRef child in React.js?
# https://stackoverflow.com/questions/76910670/how-to-track-and-change-the-state-of-an-elements-useref-child-in-react-js
#
# skipped
#
# skipped
#
# skipped
#
# How to properly add type to useContext in react?
# https://stackoverflow.com/questions/76910669/how-to-properly-add-type-to-usecontext-in-react
#
# Is it possible to change the size of the &#39;icon&#39; property when selecting a Marker widget in google_maps_flutter?
# https://stackoverflow.com/questions/76910668/is-it-possible-to-change-the-size-of-the-icon-property-when-selecting-a-marker
#
# Not able to see activemq logs after upgrading to ActiveMQ 5.18.2 version
# ...
