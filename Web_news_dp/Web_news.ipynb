# %% [markdown]
# ## NEWS

# %% [markdown]
# ### APNEWS
#
# - It has show more

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Set the URL to request
url = 'https://apnews.com/hub/migration'

# Headers to simulate a browser visit
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Make the request with headers to mimic a browser
response = requests.get(url, headers=headers)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# Search for divs by class name where data is structured as provided
page_items = soup.find_all('div', class_='PageList-items-item')

# Initialize a list to hold the extracted data
data = []

# Iterate through each item and extract the necessary information
for item in page_items:
    page_promo = item.find('div', class_='PagePromo')
    if page_promo:
        link_tag = page_promo.find('a', class_='Link')
        link = link_tag['href'] if link_tag else 'No link available'
        title_tag = page_promo.find('h3', class_='PagePromo-title')
        title = title_tag.text.strip() if title_tag else 'No title available'
        description_tag = page_promo.find('div', class_='PagePromo-description')
        description = description_tag.text.strip() if description_tag else 'No description available'
        
        # Correct targeting of the date element using the data-date attribute
        date_tag = page_promo.find('span', attrs={'data-date': True})
        date = date_tag.text if date_tag else 'Date not available'

        # Append the extracted information to the list
        data.append({
            'Link': link,
            'Title': title,
            'Description': description,
            'Date': date
        })

# Create a DataFrame from the extracted data
data_df = pd.DataFrame(data)

# Display the DataFrame
data_df.head(10)
# Out:
#                                                 Link  \
# 0  https://apnews.com/article/paris-migrants-evic...
# 1  https://apnews.com/article/britain-rwanda-migr...
# 2  https://apnews.com/article/france-migrants-dea...
# 3  https://apnews.com/article/uk-italy-migrants-c...
# 4  https://apnews.com/article/uk-rwanda-migrants-...
# 5  https://apnews.com/article/migration-syria-ref...
# 6  https://apnews.com/article/italy-migration-res...
# 7  https://apnews.com/article/spain-ceuta-migrant...
# 8  https://apnews.com/article/uk-rwanda-migrants-...
# 9  https://apnews.com/article/migrants-lesbos-cem...
#
#                                                Title  \
# 0  Police clear out a migrant camp in central Par...
# 1  Human rights groups condemn UK plan to send as...
# 2  5 migrants die while crossing the English Chan...
# 3  UK home secretary to visit Italy to discuss st...
# 4  UK Parliament approves Rwanda deportation bill...
# 5  UN refugee agency tells Cyprus to stick to the...
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Set the URL to request
url = 'https://apnews.com/hub/migration'

# Make the request and store the response
response = requests.get(url)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# Search for divs by class name where data is structured as provided
page_items = soup.find_all('div', class_='PageList-items-item')

# Initialize a list to hold the extracted data
data = []

# Iterate through each item and extract the necessary information
for item in page_items:
    page_promo = item.find('div', class_='PagePromo')
    if page_promo:
        link_tag = page_promo.find('a', class_='Link')
        link = link_tag['href'] if link_tag else 'No link available'
        title_tag = page_promo.find('h3', class_='PagePromo-title')
        title = title_tag.text.strip() if title_tag else 'No title available'
        description_tag = page_promo.find('div', class_='PagePromo-description')
        description = description_tag.text.strip() if description_tag else 'No description available'
        date_tag = page_promo.find('span', {'data-date': True})
        date = date_tag.text if date_tag else 'No date available'

        # Append the extracted information to the list
        data.append({
            'PagePromo-title': title,
            'Summary': description,
            'Link': link,
            'PagePromo-date': date,
            'PagePromo-description': description,
            'Source': 'Apnews'
        })

# Create a DataFrame from the extracted data
data_df = pd.DataFrame(data)

# Display the DataFrame
data_df.head(10)
# Out:
#                                                 Link  \
# 0  https://apnews.com/article/paris-migrants-evic...
# 1  https://apnews.com/article/britain-rwanda-migr...
# 2  https://apnews.com/article/france-migrants-dea...
# 3  https://apnews.com/article/uk-italy-migrants-c...
# 4  https://apnews.com/article/uk-rwanda-migrants-...
# 5  https://apnews.com/article/migration-syria-ref...
# 6  https://apnews.com/article/italy-migration-res...
# 7  https://apnews.com/article/spain-ceuta-migrant...
# 8  https://apnews.com/article/uk-rwanda-migrants-...
# 9  https://apnews.com/article/migrants-lesbos-cem...
#
#                                              Summary PagePromo-date  \
# 0  French police have evicted migrants from a mak...
# 1                           No description available
# 2                           No description available
# 3                           No description available
# 4                           No description available
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Set the URL to request
url = 'https://apnews.com/hub/migration'

# Make the request and store the response
response = requests.get(url)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# Search for divs by class name where data is structured as provided
page_items = soup.find_all('div', class_='PageList-items-item')

# Initialize a list to hold the extracted data
data = []

# Iterate through each item and extract the necessary information
for item in page_items:
    page_promo = item.find('div', class_='PagePromo')
    if page_promo:
        link_tag = page_promo.find('a', class_='Link')
        link = link_tag['href'] if link_tag else 'No link available'
        title_tag = page_promo.find('h3', class_='PagePromo-title')
        title = title_tag.text.strip() if title_tag else 'No title available'
        description_tag = page_promo.find('div', class_='PagePromo-description')
        description = description_tag.text.strip() if description_tag else 'No description available'
        
        # Correct targeting of the date element using the data-date attribute
        date_tag = page_promo.find('span', attrs={'data-date': True})
        date = date_tag.text if date_tag else 'Date not available'

        # Append the extracted information to the list
        data.append({
            'Link': link,
            'Summary': description,
            'PagePromo-date': date,
            'PagePromo-title': title,
            'PagePromo-description': description
        })

# Create a DataFrame from the extracted data
data_df_apnews = pd.DataFrame(data)

# Display the DataFrame
data_df_apnews.head(10)
# Out:
#                                                 Link  \
# 0  https://apnews.com/article/paris-migrants-evic...
# 1  https://apnews.com/article/britain-rwanda-migr...
# 2  https://apnews.com/article/france-migrants-dea...
# 3  https://apnews.com/article/uk-italy-migrants-c...
# 4  https://apnews.com/article/uk-rwanda-migrants-...
# 5  https://apnews.com/article/migration-syria-ref...
# 6  https://apnews.com/article/italy-migration-res...
# 7  https://apnews.com/article/spain-ceuta-migrant...
# 8  https://apnews.com/article/uk-rwanda-migrants-...
# 9  https://apnews.com/article/migrants-lesbos-cem...
#
#                                              Summary PagePromo-date  \
# 0  French police have evicted migrants from a mak...
# 1                           No description available
# 2                           No description available
# 3                           No description available
# 4                           No description available
# ...

# %%
data_df_apnews.shape
# Out:
# (35, 5)

# %% [markdown]
# ### theGuardian
#
# - It has pages

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Set the URL to request
url = 'https://www.theguardian.com/world/migration'

# Headers to simulate a browser visit
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Make the request with headers
response = requests.get(url, headers=headers)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# Initialize a list to hold the extracted data
data = []

# Extract information from the specific parts of the page
for section in soup.find_all('section', class_='fc-container'):
    date_text = section.find('time', class_='fc-date-headline').text.strip()
    articles = section.find_all('div', class_='fc-item__container')
    for article in articles:
        title_tag = article.find('a', class_='fc-item__link')
        link = title_tag['href'] if title_tag else 'No link available'
        title = title_tag.text.strip() if title_tag else 'No title available'
        timestamp_tag = article.find('time', class_='fc-item__timestamp')
        published_time = timestamp_tag['datetime'] if timestamp_tag else 'Timestamp not available'
        
        # Append the extracted information to the list
        data.append({
            'Date': date_text,
            'Link': link,
            'Title': title,
            'Published Time': published_time
        })

# Create a DataFrame from the extracted data
data_df = pd.DataFrame(data)

# Display the DataFrame
data_df.head(10)
# Out:
#             Date                                               Link  \
# 0  23 April 2024  https://www.theguardian.com/politics/live/2024...
# 1  23 April 2024  https://www.theguardian.com/politics/live/2024...
# 2  20 April 2024  https://www.theguardian.com/uk-news/2024/apr/2...
# 3  19 April 2024  https://www.theguardian.com/world/2024/apr/19/...
# 4  19 April 2024  https://www.theguardian.com/commentisfree/2024...
# 5  18 April 2024  https://www.theguardian.com/politics/live/2024...
# 6  18 April 2024  https://www.theguardian.com/world/2024/apr/18/...
# 7  18 April 2024  https://www.theguardian.com/global-development...
# 8  17 April 2024  https://www.theguardian.com/politics/live/2024...
# 9  16 April 2024  https://www.theguardian.com/commentisfree/2024...
#
#                                                Title            Published Time
# 0  Live\n                Rishi Sunak holds press ...  2024-04-23T14:01:59+0000
# ...

# %%
data_df.shape
# Out:
# (20, 4)

# %% [markdown]
# ### Ajazera

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Set the URL to request
url = 'https://www.theguardian.com/world/migration'

# Headers to simulate a browser visit
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Make the request with headers
response = requests.get(url, headers=headers)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# Initialize a list to hold the extracted data
data = []

# Extract information from the specific parts of the page
for article in soup.find_all('article', class_='gc'):
    # Extracting the title and link
    title_tag = article.find('a', class_='u-clickable-card__link')
    title = title_tag.text.strip() if title_tag else 'No title available'
    link = title_tag['href'] if title_tag else 'No link available'
    
    # Extracting the publication date
    date_tag = article.find('span', class_='screen-reader-text')
    date_text = date_tag.text.replace('Published On ', '').strip() if date_tag else 'Date not available'
    
    # Extracting the description
    description_tag = article.find('div', class_='gc__excerpt')
    description = description_tag.text.strip() if description_tag else 'No description available'
    
    # Append the extracted information to the list
    data.append({
        'Title': title,
        'Link': 'https://www.theguardian.com' + link,
        'Published Date': date_text,
        'Description': description
    })

# Create a DataFrame from the extracted data
data_df = pd.DataFrame(data)

# Display the DataFrame
data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### https://timesofmalta.com/news/migration

# %%
https://timesofmalta.com/news/migration

# %% [markdown]
# ### Gooogle News

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup

root = "https://www.google.com/"
link = "https://www.google.com/search?q=biden&tbm=nws&source=lnt&tbs=sbd:1&sa=X&ved=0ahUKEwjAvsKDyOXtAhXBhOAKHXWdDgcQpwUIKQ&biw=1604&bih=760&dpr=1.2"

def news(link):
    req = Request(link, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(req).read()
    soup = BeautifulSoup(webpage, 'html5lib')
    for item in soup.find_all('div', attrs={'class': 'ZINbbc xpd O9g5cc uUPGi'}):
        raw_link = (item.find('a', href=True)['href'])
        link = (raw_link.split("/url?q=")[1]).split('&sa=U&')[0]
                
        title = (item.find('div', attrs={'class': 'BNeawe vvjwJb AP7Wnd'}).get_text())
        description = (item.find('div', attrs={'class': 'BNeawe s3v9rd AP7Wnd'}).get_text())

        title = title.replace(",", "")
        description = description.replace(",", "")

        time = description.split(" · ")[0]
        descript = description.split(" · ")[1]
        
        print(title)
        print(time)
        print(descript)
        print(link)
        document = open("Data.csv", "a")
        document.write("{}, {}, {}, {} \n".format(title, time, descript, link))
        document.close()
        
    next = soup.find('a', attrs={'aria-label':'Next page'})
    next = (next['href'])
    link = root + next
    news(link)
news(link)

# %%
from pygooglenews import GoogleNews
gn = GoogleNews(country = 'UK')

def get_titles(search):
    stories = []
    search = gn.search(search)
    newsitem = search['entries']
    for item in newsitem:
        story = {
            'title': item.title,
            'link': item.link
        }
        stories.append(story)
    return stories

print(get_titles('lockdown'))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
from gnews import GNews

# Create an instance of GNews
google_news = GNews()

# Get news articles about NASA
articles = google_news.get_news('NASA')

# Initialize lists to store data
dates = []
sources = []
links = []
titles = []
summaries = []

# Extract data from each article
for article in articles:
    dates.append(article['date'])
    sources.append(article['source'])
    links.append(article['link'])
    titles.append(article['title'])
    summaries.append(article['desc'])

# Create a DataFrame
df = pd.DataFrame({
    'Source': sources,
    'Link': links,
    'Title': titles,
    'Summary': summaries
})

# Display the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 19
#      17 # Extract data from each article
#      18 for article in articles:
# ---> 19     dates.append(article['date'])
#      20     sources.append(article['source'])
#      21     links.append(article['link'])
#
# KeyError: 'date'

# %% [markdown]
# # Using GNews
#
# - https://github.com/ranahaani/GNews

# %%
from gnews import GNews

google_news = GNews()
pakistan_news = google_news.get_news('Pakistan')
print(pakistan_news[0])

df = pd.DataFrame(pakistan_news)

# Display the DataFrame
df

df = pd.DataFrame(pakistan_news)

# Display the DataFrame
df
# Out:
# {'title': 'Why is Iran’s President Ebrahim Raisi visiting Pakistan? - Al Jazeera English', 'description': 'Why is Iran’s President Ebrahim Raisi visiting Pakistan?  Al Jazeera EnglishIran, Pakistan leaders vow to boost trade, strengthen security cooperation  The Associated PressIran, Pakistan Seek to Patch Up Ties With Pledge to Boost Trade  Bloomberg', 'published date': 'Mon, 22 Apr 2024 10:45:56 GMT', 'url': 'https://news.google.?oc=5&hl=en-GB&gl=GB&ceid=GB:en', 'publisher': {'href': 'https://www.aljazeera.com', 'title': 'Al Jazeera English'}}

# %% [markdown]
# ## GNEWS
# - https://github.com/ranahaani/GNews

# %%
# pip install gnews
# pip3 install newspaper3k

from gnews import GNews
import pandas as pd
import re

# Create an instance of GNews with parameters
# google_news = GNews(language='en', country='US', period='7d', start_date=None, end_date=None, max_results=10, exclude_websites=['yahoo.com', 'cnn.com'],proxy=proxy)
google_news = GNews(language='en', max_results=10)

# Search for NEWS with"Migration"
migration_news = google_news.get_news('Migration')
# print(migration_news[0])

# Display in DataFrame
df = pd.DataFrame(migration_news)

# Extract just the 'title' value from the 'publisher' column
df['publisher'] = df['publisher'].apply(lambda x: x['title'])

# Display the DataFrame
df
# Out:
#                                                title  \
# 0  Hundreds of migrants arrive on trains at El Pa...
# 1  I Helped Thousands of Migrants at the U.S. Bor...
# 2  Rwanda explained: From politics to human right...
# 3  Hope Hostel in Rwanda says it's ready for firs...
# 4  Rwanda's Hope Hostel once housed young genocid...
# 5  Venezuelan Migrants Drive USD 529.1M Boost to ...
# 6  Migrants staying at Yarmouth motel move off Ca...
# 7  Some migrants flown by DeSantis to Martha’s Vi...
# 8  Migrants flown to Martha's Vineyard closer to ...
# 9  Migrants flown to Martha's Vineyard now consid...
#
#                                          description  \
# 0  Hundreds of migrants arrive on trains at El Pa...
# 1  I Helped Thousands of Migrants at the U.S. Bor...
# 2  Rwanda explained: From politics to human right...
# 3  Hope Hostel in Rwanda says it's ready for firs...
# 4  Rwanda's Hope Hostel once housed young genocid...
# 5  Venezuelan Migrants Drive USD 529.1M Boost to ...
# ...

# %% [markdown]
# Generating the countries using the country_data.son file

# %%
import pandas as pd
import re
import json

# Load country data from the uploaded JSON file
with open('country_data.json', 'r', encoding='utf-8') as file:
    country_data = json.load(file)

# Generate a regex pattern for each country using preferred names and regex from the data
country_patterns = {}
for country in country_data:
    preferred_name = country["#country+name+preferred"]
    regex = country["#country+regex"]
    # Use the regex if it's not empty; otherwise, escape the preferred name and use it as regex
    pattern = re.escape(preferred_name) if not regex else regex
    country_patterns[preferred_name] = re.compile(pattern, re.IGNORECASE)


df_new = df

# Function to extract country names or return "No Country Names"
def extract_countries(text):
    countries = set()
    for country, pattern in country_patterns.items():
        if pattern.search(text):
            countries.add(country)
    return ', '.join(countries) if countries else 'No Country Names'

# Apply the function to 'title' and 'description' columns and handle duplicates
df_new['Country'] = df_new.apply(lambda row: extract_countries(row['title']) + ', ' + extract_countries(row['description']), axis=1)
df_new['Country'] = df_new['Country'].apply(lambda x: ', '.join(set(x.split(', '))))  # Remove duplicates

# Display the DataFrame
df_new
# Out:
#                                                title  \
# 0  Hundreds of migrants arrive on trains at El Pa...
# 1  I Helped Thousands of Migrants at the U.S. Bor...
# 2  Rwanda explained: From politics to human right...
# 3  Hope Hostel in Rwanda says it's ready for firs...
# 4  Rwanda's Hope Hostel once housed young genocid...
# 5  Venezuelan Migrants Drive USD 529.1M Boost to ...
# 6  Migrants staying at Yarmouth motel move off Ca...
# 7  Some migrants flown by DeSantis to Martha’s Vi...
# 8  Migrants flown to Martha's Vineyard closer to ...
# 9  Migrants flown to Martha's Vineyard now consid...
#
#                                          description  \
# 0  Hundreds of migrants arrive on trains at El Pa...
# 1  I Helped Thousands of Migrants at the U.S. Bor...
# 2  Rwanda explained: From politics to human right...
# 3  Hope Hostel in Rwanda says it's ready for firs...
# 4  Rwanda's Hope Hostel once housed young genocid...
# 5  Venezuelan Migrants Drive USD 529.1M Boost to ...
# ...

# %% [markdown]
# ## Multiple search

# %%
from gnews import GNews
import pandas as pd

# Create an instance of GNews with English language and default settings
google_news = GNews(language='en', max_results=20)

# Construct a query to fetch news that includes any of several keywords along with "Pakistan"
query = "(Migration OR Floods OR Conflict OR migrant OR refugee OR IDP) AND Pakistan"

# Search for news with the constructed query
combined_search_news = google_news.get_news(query)

# Convert the news results into a DataFrame
df = pd.DataFrame(combined_search_news)

# Extract just the 'title' value from the 'publisher' column
df['publisher'] = df['publisher'].apply(lambda x: x['title'])

# Display the DataFrame
df
# Out:
#                                                 title  \
# 0   Anti-migrant raids push millions of Afghans in...
# 1             Devastating floods in Pakistan - UNICEF
# 2   Imran Khan's conflict with the military establ...
# 3   Pakistan must halt unlawful deportation of Afg...
# 4   Rainstorms Kill More Than 130 in Afghanistan a...
# 5   Pakistan extends registered Afghan refugees' s...
# 6   Weather tracker: rains bring deadly flash floo...
# 7   Pakistani smuggling network busted in Romania ...
# 8   2022 Pakistan Floods - Center for Disaster Phi...
# 9   What is behind Iran-Pakistan attacks and could...
# 10  Pakistan: Widespread Abuses Force Afghans to L...
# 11  Heavy rains, lightning in Pakistan kill at lea...
# 12  Refugee Rights are Human Rights! Afghan Refuge...
# 13  Climate Migration 101: An Explainer - Pakistan...
# 14  Displaced to Cities: Conflict, Climate Change,...
# 15  Pakistan floods a 'litmus test' for climate ju...
# ...

# %%
from gnews import GNews
import pandas as pd

# Create an instance of GNews with English language and default settings
google_news = GNews(language='en', max_results=50)

# Get today's date and yesterday's date as datetime objects
today = datetime.now()
yesterday = datetime.now() - timedelta(days=1)

# Set the date range for the search: from yesterday to today
google_news.start_date = yesterday
google_news.end_date = today

# Define a list of countries you want to include in your searches
countries = ['Pakistan', 'India', 'Bangladesh', 'Afghanistan', 'Syria']

# Define your search terms
terms = "Migration OR Floods OR Conflict OR migrant OR refugee OR IDP"

# Initialize an empty list to collect all news items
all_news_items = []

# Loop through each country, performing a search including the country in the query
for country in countries:
    query = f"({terms}) AND {country}"
    news_results = google_news.get_news(query)
    for news in news_results:
        news['Country_Search'] = country  # Add the country name as a new key-value pair in each news item dictionary
    all_news_items.extend(news_results)

# Convert all news items into a DataFrame
df = pd.DataFrame(all_news_items)

# Extract just the 'title' value from the 'publisher' column
df['publisher'] = df['publisher'].apply(lambda x: x['title'])

# Display the DataFrame
df
# Out:
#                                                  title  \
# 0    Imran Khan's conflict with the military establ...
# 1    Pakistan's brutal deportation of Afghans widen...
# 2    Australia was 'lucky to have' Pakistani refuge...
# 3    Afghan Migrants' 'PoR' Cards in Pakistan Exten...
# 4    Nearly 2,000 Afghan migrants returned from Ira...
# ..                                                 ...
# 112  Blinken is back in the Middle East this week. ...
# 113  France pushes efforts in Lebanon to prevent wa...
# 114  France pushes efforts in Lebanon to prevent wa...
# 115  I travelled to Lebanon to help refugees 'find ...
# 116  Minister says UK is 'overwhelmed' by small boa...
#
#                                            description  \
# 0    Imran Khan's conflict with the military establ...
# 1    Pakistan's brutal deportation of Afghans widen...
# 2    Australia was 'lucky to have' Pakistani refuge...
# 3    Afghan Migrants' 'PoR' Cards in Pakistan Exten...
# ...

# %%
from gnews import GNews
import pandas as pd
import json
from datetime import datetime, timedelta

# Load country data from the JSON file
with open('./countries_all.json') as f:
    country_data = json.load(f)
countries = [country['name'] for country in country_data]  # Extract country names

# Create an instance of GNews with English language and default settings
google_news = GNews(language='en', max_results=50)

# Get today's date and yesterday's date as datetime objects
today = datetime.now()
yesterday = datetime.now() - timedelta(days=1)

# Set the date range for the search: from yesterday to today
google_news.start_date = yesterday
google_news.end_date = today

# Define your search terms
terms = "Migration OR Floods OR Conflict OR migrant OR refugee OR IDP"

# Initialize an empty list to collect all news items
all_news_items = []

# Loop through each country, performing a search including the country in the query
for country in countries:
    query = f"({terms}) AND {country}"
    news_results = google_news.get_news(query)
    for news in news_results:
        news['Country_Search'] = country  # Add the country name as a new key-value pair in each news item dictionary
    all_news_items.extend(news_results)

# Convert all news items into a DataFrame
df = pd.DataFrame(all_news_items)

# Extract just the 'title' value from the 'publisher' column
df['publisher'] = df['publisher'].apply(lambda x: x['title'])

# Display the DataFrame
df

# %% [markdown]
# ## Final Output

# %%
from gnews import GNews
import pandas as pd
import json
from datetime import datetime, timedelta
import concurrent.futures

# Load country data from the JSON file
with open('./countries_all.json') as f:
    country_data = json.load(f)
countries = [country['name'] for country in country_data]  # Extract country names

# Create an instance of GNews with English language and default settings
google_news = GNews(language='en', max_results=10)
GNews.get_news_by_site(cnn.com)


# Get today's date and yesterday's date as datetime objects
today = datetime.now()
yesterday = datetime.now() - timedelta(days=1)

# Set the date range for the search: from yesterday to today
google_news.start_date = yesterday
google_news.end_date = today


# Define your search terms
terms = "Migration OR Flood OR Conflict OR migrant OR asylum OR displacement OR refugee OR IDP"

def fetch_news(country):
    query = f"({terms}) AND {country}"
    news_results = google_news.get_news(query)
    for news in news_results:
        news['Country_Search'] = country
    return news_results

# Use ThreadPoolExecutor to run searches in parallel
all_news_items = []
with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    future_to_news = {executor.submit(fetch_news, country): country for country in countries}
    for future in concurrent.futures.as_completed(future_to_news):
        all_news_items.extend(future.result())

# Convert all news items into a DataFrame
df = pd.DataFrame(all_news_items)

# Extract just the 'title' value from the 'publisher' column
df['publisher'] = df['publisher'].apply(lambda x: x['title'])

# Display the DataFrame
df
# Out:
#                                                   title  \
# 0     Ghana retains 10th position with lowest fuel p...
# 1     Milei vows roadmap towards Argentine sovereign...
# 2     UK will 'not take back asylum seekers from Ire...
# 3            Houthis damage tanker, down US drone - MSN
# 4     Small boat migrant arrivals by late April at h...
# ...                                                 ...
# 1051  Houthi Rebels Escalate Conflict with Downed $3...
# 1052  Saudi project clears 797 Houthi mines in Yemen...
# 1053  Downing of U.S. UAV by Houthi Rebels in Yemen ...
# 1054  Yemen's Al Houthi militant attacks no threat t...
# 1055  Saudi FM: Gaza committee stresses need for san...
#
#                                             description  \
# 0     Ghana retains 10th position with lowest fuel p...
# 1     Milei vows roadmap towards Argentine sovereign...
# 2     UK will 'not take back asylum seekers from Ire...
# 3             Houthis damage tanker, down US drone  MSN
# ...

# %%
# df.to_csv('news_data.csv', index=False)

df.to_csv('migration_news_2.csv', index=False, encoding='utf-8-sig')

# %%
from gnews import GNews
import pandas as pd
import json
from datetime import datetime, timedelta
import concurrent.futures

# Load country data from the JSON file
with open('./countries_all.json') as f:
    country_data = json.load(f)
countries = [country['name'] for country in country_data]  # Extract country names

# Create an instance of GNews with English language and default settings
google_news = GNews(language='en', max_results=10)

# Get today's date and yesterday's date as datetime objects
today = datetime.now()
yesterday = datetime.now() - timedelta(days=1)

# Set the date range for the search: from yesterday to today
google_news.start_date = yesterday
google_news.end_date = today

# Define your search terms
terms = "Migration OR Flood OR Conflict OR migrant OR asylum OR displacement OR refugee OR IDP"

def fetch_news(country):
    query = f"({terms}) AND {country}"
    news_results = google_news.get_news(query)
    for news in news_results:
        news['Country_Search'] = country
    return news_results

# Use ThreadPoolExecutor to run searches in parallel
all_news_items = []
with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    future_to_news = {executor.submit(fetch_news, country): country for country in countries}
    for future in concurrent.futures.as_completed(future_to_news):
        all_news_items.extend(future.result())

# Convert all news items into a DataFrame
df = pd.DataFrame(all_news_items)

# Extract just the 'title' value from the 'publisher' column
df['publisher'] = df['publisher'].apply(lambda x: x['title'])

# Check for specific terms in title or description
def check_terms(text):
    keywords = ["Migration", "Flood", "Conflict", "migrant", "asylum", "displacement", "refugee", "IDP"]
    return any(keyword in text for keyword in keywords)

# Apply function to create a new column based on title and description
df['Relevant_Term_Found'] = df.apply(lambda x: check_terms(x['title']) or check_terms(x['description']), axis=1)

# Display the DataFrame

df
# Out:
#                                                   title  \
# 0     Milei vows roadmap towards Argentine sovereign...
# 1     How Portugal's Carnation Revolution changed th...
# 2     Ghana retains 10th position with lowest fuel p...
# 3     Algeria asked by Europe to boost gas supply - ...
# 4     Migrants eyeing Europe bide their time in Tuni...
# ...                                                 ...
# 1116  Houthi Rebels Escalate Conflict with Downed $3...
# 1117  Downing of U.S. UAV by Houthi Rebels in Yemen ...
# 1118  Yemen's Al Houthi militant attacks no threat t...
# 1119  Saudi FM: Gaza committee stresses need for san...
# 1120  Where refugees in Florida are coming from - NB...
#
#                                             description  \
# 0     Milei vows roadmap towards Argentine sovereign...
# 1     How Portugal's Carnation Revolution changed th...
# 2     Ghana retains 10th position with lowest fuel p...
# 3     Algeria asked by Europe to boost gas supply  A...
# ...

# %% [markdown]
# ## Media Round UP

# %%
from gnews import GNews
import pandas as pd
import json
from datetime import datetime, timedelta
import concurrent.futures

# Load country data from the JSON file
with open('./countries_all.json') as f:
    country_data = json.load(f)
countries = [country['name'] for country in country_data]  # Extract country names

# Create an instance of GNews with English language and default settings
google_news = GNews(language='en', max_results=10)

# Get today's date and yesterday's date as datetime objects
today = datetime.now()
yesterday = datetime.now() - timedelta(days=1)

# Set the date range for the search: from yesterday to today
google_news.start_date = yesterday
google_news.end_date = today

# Define your search terms
terms = "Migration OR Flood OR Conflict OR migrant OR asylum OR displacement OR refugee OR IDP"

def fetch_news(country):
    query = f"({terms}) AND {country}"
    news_results = google_news.get_news(query)
    for news in news_results:
        news['Country_Search'] = country
    return news_results

# Use ThreadPoolExecutor to run searches in parallel
all_news_items = []
with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    future_to_news = {executor.submit(fetch_news, country): country for country in countries}
    for future in concurrent.futures.as_completed(future_to_news):
        all_news_items.extend(future.result())

# Convert all news items into a DataFrame
df = pd.DataFrame(all_news_items)

# Extract just the 'title' value from the 'publisher' column
df['publisher'] = df['publisher'].apply(lambda x: x['title'])

# Function to check for specific terms in title or description
def check_terms(text):
    keywords = ["migration", "flood", "conflict", "migrant", "asylum", "displacement", "refugee", "idp"]
    # Convert text to lower case to make the search case-insensitive
    text_lower = text.lower()
    return any(keyword in text_lower for keyword in keywords)

# Apply function to create a new column based on title and description
df['Relevant_Term_Found'] = df.apply(lambda x: check_terms(x['title']) or check_terms(x['description']), axis=1)

# Convert the 'published date' from text to datetime and reformat
df['published date'] = pd.to_datetime(df['published date'], format='%a, %d %b %Y %H:%M:%S %Z').dt.strftime('%d/%m/%Y')

# filter for thse with relevant term
filtered_df = df[df['Relevant_Term_Found'] == True]
filtered_df
# Out:
#                                                   title  \
# 7     Middle East Conflicts and Diplomatic Efforts -...
# 8     UK will 'not take back asylum seekers from Ire...
# 9     Small boat migrant arrivals by late April at h...
# 13    Seven dead as minibus believed to be smuggling...
# 16    Minister Fauziyah discusses migrant workers wi...
# ...                                                 ...
# 1088  Migrant families find community at Brooklyn So...
# 1089  NGO, migrants call for end to child beggars: I...
# 1095  Maps of War: Mapping conflict through the cent...
# 1105  Houthi Rebels Escalate Conflict with Downed $3...
# 1109  Where refugees in Florida are coming from - NB...
#
#                                             description published date  \
# 7     Middle East Conflicts and Diplomatic Efforts  ...     28/04/2024
# 8     UK will 'not take back asylum seekers from Ire...     29/04/2024
# 9     Small boat migrant arrivals by late April at h...     28/04/2024
# ...

# %%
filtered_df.to_csv('migration_news.csv', index=False, encoding='utf-8-sig')
